# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.141937
# Nearest to if: periodically, licentious, gail, granting, trumbull, playoffs, forebears, pandora,
# Nearest to many: ocs, css, wolverine, castor, proves, listerine, alomari, identically,
# Nearest to a: ostrich, discoverers, headwaters, pure, hint, avtovaz, idealistic, charlestown,
# Nearest to used: praia, cedric, synergies, jaian, widower, boosting, rhetoricians, roebuck,
# Nearest to s: discount, highs, promotions, tique, sawyer, parties, shoguns, assembly,
# Nearest to most: iic, chthonic, rewrote, prior, hyphen, kassites, crm, cantigas,
# Nearest to were: everlasting, pesce, autobiographies, austen, jiangxi, rapping, exiles, magda,
# Nearest to while: bilinear, ed, liqueur, dhahran, bulgaria, memorization, registrar, pipelining,
# Nearest to into: hamza, negotiate, lichfield, attractiveness, valyria, spitfire, classifying, jenner,
# Nearest to in: labor, secured, alfonso, upholds, midshipman, renamo, hydride, fainter,
# Nearest to no: impart, predictive, opcode, circumstantial, yankees, yesterday, baseline, amazed,
# Nearest to be: nullification, memorable, guam, stripping, signifier, rcito, paralipomena, ripe,
# Nearest to also: reappeared, odi, stringing, allowance, gb, officers, bust, dodecanese,
# Nearest to that: liouville, maintainer, jenny, grim, emblazoned, hereafter, evangelium, speculators,
# Nearest to between: types, epr, morphologically, upheavals, scheme, whorf, impoverished, sagan,
# Nearest to world: tezuka, fulfilling, nottinghamshire, coppola, philological, ioi, privatisation, dacian,
# Average loss at step 2000: 4.355648
# Average loss at step 4000: 3.862291
# Average loss at step 6000: 3.790908
# Average loss at step 8000: 3.684382
# Average loss at step 10000: 3.612094
# Nearest to if: forrest, periodically, ratings, trumbull, resting, encompass, pandora, licentious,
# Nearest to many: little, ocs, bump, proterozoic, several, parody, hypothesised, omen,
# Nearest to a: the, hairpin, alfv, margin, his, ceded, assemblers, herbie,
# Nearest to used: written, diploid, bannister, gladiators, relapse, citrus, widower, praia,
# Nearest to s: and, his, unicellular, assembly, goidelic, mormons, catamarans, evasion,
# Nearest to most: codepoint, empires, rewrote, gaseous, butterflies, nite, kassites, fatherland,
# Nearest to were: are, was, have, everlasting, had, almost, pesce, sediments,
# Nearest to while: memorization, ed, liqueur, methodism, tetrahedron, tactics, kendo, dhahran,
# Nearest to into: sergius, hamza, nerva, carter, songbook, cryptozoologists, daleks, negotiate,
# Nearest to in: of, at, from, on, with, intrepid, panspermia, supports,
# Nearest to no: predictive, circumstantial, daley, impart, madeira, there, sprinkled, amazed,
# Nearest to be: have, is, are, kiosks, unconstitutional, tag, conferring, was,
# Nearest to also: which, spoils, there, it, he, stringing, ghazni, sometimes,
# Nearest to that: which, prerequisite, it, bolstered, nucleon, this, riffing, we,
# Nearest to between: with, steal, whorf, busoni, in, epr, carey, morphologically,
# Nearest to world: dacian, tezuka, philological, nottinghamshire, privatisation, kites, legends, histological,
# Average loss at step 12000: 3.601818
# Average loss at step 14000: 3.569077
# Average loss at step 16000: 3.411167
# Average loss at step 18000: 3.453475
# Average loss at step 20000: 3.537920
# Nearest to if: forrest, periodically, could, encompass, marino, ratings, when, gimmick,
# Nearest to many: some, several, other, these, all, most, lookahead, omen,
# Nearest to a: alfv, hairpin, this, no, ranking, dardanelles, writs, criticisms,
# Nearest to used: written, bannister, known, seen, mackey, relapse, polymer, citrus,
# Nearest to s: taxable, philanthropy, petroleum, implements, mohel, karim, faroe, supports,
# Nearest to most: some, codepoint, more, rewrote, nite, poetical, groom, many,
# Nearest to were: are, was, have, had, be, sediments, by, is,
# Nearest to while: memorization, methodism, ejecta, revenues, lame, tetrahedron, kendo, are,
# Nearest to into: from, bring, hamza, carter, daleks, nerva, eff, depict,
# Nearest to in: at, on, with, from, and, by, without, makkah,
# Nearest to no: predictive, there, impart, circumstantial, sprinkled, any, a, daley,
# Nearest to be: have, been, was, were, is, are, unsurprising, let,
# Nearest to also: which, generally, who, often, now, phages, still, officers,
# Nearest to that: which, but, what, monolith, reductionism, who, this, lendl,
# Nearest to between: with, steal, busoni, whorf, at, implementations, from, epr,
# Nearest to world: legends, dacian, asb, tezuka, octal, privatisation, philological, lyrical,
# Average loss at step 22000: 3.498539
# Average loss at step 24000: 3.489505
# Average loss at step 26000: 3.483700
# Average loss at step 28000: 3.476193
# Average loss at step 30000: 3.501104
# Nearest to if: when, where, encompass, though, although, forrest, philanthropy, marino,
# Nearest to many: some, several, these, most, all, their, other, omen,
# Nearest to a: any, this, the, another, mascarene, dictum, alfv, too,
# Nearest to used: written, known, responsible, produced, found, polymer, called, referred,
# Nearest to s: his, diglossia, shelled, beaton, wickham, reproductive, goidelic, outboard,
# Nearest to most: some, more, codepoint, many, poetical, molarity, filial, zar,
# Nearest to were: are, was, have, had, been, aspired, be, is,
# Nearest to while: although, tetrahedron, but, coptic, is, are, was, revenues,
# Nearest to into: from, through, hamza, bring, nerva, depict, opencourseware, muons,
# Nearest to in: at, on, of, during, under, until, bodhisattvas, by,
# Nearest to no: any, there, predictive, sprinkled, metre, possible, coroner, circumstantial,
# Nearest to be: have, been, is, was, were, lifeform, are, become,
# Nearest to also: often, which, who, generally, still, now, stringing, phages,
# Nearest to that: which, this, what, but, mug, however, riffing, lia,
# Nearest to between: with, remarry, busoni, deprecating, carey, outside, types, whorf,
# Nearest to world: legends, octal, postcolonial, asb, philological, dacian, lyrical, privatisation,
# Average loss at step 32000: 3.501926
# Average loss at step 34000: 3.492392
# Average loss at step 36000: 3.453334
# Average loss at step 38000: 3.304554
# Average loss at step 40000: 3.430992
# Nearest to if: when, where, for, though, associative, encompass, philanthropy, then,
# Nearest to many: some, several, these, most, both, various, landmasses, numerous,
# Nearest to a: the, herbie, alfv, hairpin, any, dorm, debtors, another,
# Nearest to used: written, found, known, responsible, seen, available, referred, knut,
# Nearest to s: shelled, his, faroe, secretly, sultans, nutmeg, eschatological, her,
# Nearest to most: more, some, many, codepoint, among, less, quite, molarity,
# Nearest to were: are, have, was, been, had, aspired, while, prescribes,
# Nearest to while: although, when, where, tetrahedron, after, are, though, but,
# Nearest to into: from, through, hamza, nerva, across, signifier, until, soyuz,
# Nearest to in: of, from, during, within, at, until, abominable, grunwald,
# Nearest to no: any, metre, predictive, semantics, there, alone, scandinavia, daley,
# Nearest to be: have, been, is, being, resist, was, are, derbyshire,
# Nearest to also: often, still, which, generally, there, who, usually, never,
# Nearest to that: which, what, this, however, it, roh, who, whom,
# Nearest to between: with, from, remarry, within, rts, carey, busoni, outside,
# Nearest to world: asb, u, lyrical, inflation, coppola, latins, cider, isoleucine,
# Average loss at step 42000: 3.435590
# Average loss at step 44000: 3.451192
# Average loss at step 46000: 3.446956
# Average loss at step 48000: 3.352979
# Average loss at step 50000: 3.381618
# Nearest to if: when, where, though, although, philanthropy, sinhalese, forrest, while,
# Nearest to many: some, several, these, most, both, various, numerous, all,
# Nearest to a: the, alfv, another, any, no, hairpin, mckernan, herbie,
# Nearest to used: written, known, referred, responsible, found, considered, able, available,
# Nearest to s: shelled, yellowish, backhand, reproductive, glc, bracewell, and, sata,
# Nearest to most: more, some, many, less, among, beneficent, codepoint, molarity,
# Nearest to were: are, was, have, had, mpr, been, reagent, firmer,
# Nearest to while: although, when, where, however, though, but, tetrahedron, after,
# Nearest to into: from, through, nerva, across, until, hamza, soyuz, depict,
# Nearest to in: within, during, since, between, until, on, from, of,
# Nearest to no: any, metre, a, semantics, scandinavia, carriages, predictive, parcels,
# Nearest to be: have, been, was, being, become, is, were, are,
# Nearest to also: often, which, still, now, then, who, generally, originally,
# Nearest to that: which, however, what, but, where, this, michaels, sunsets,
# Nearest to between: with, in, within, escalator, rts, remarry, coding, from,
# Nearest to world: lyrical, asb, latins, u, coppola, dacian, cider, temple,
# Average loss at step 52000: 3.432396
# Average loss at step 54000: 3.427020
# Average loss at step 56000: 3.440282
# Average loss at step 58000: 3.398614
# Average loss at step 60000: 3.393141
# Nearest to if: when, where, though, although, before, philanthropy, then, so,
# Nearest to many: some, several, these, various, all, most, numerous, both,
# Nearest to a: another, any, the, alfv, ceded, billiards, this, no,
# Nearest to used: written, known, responsible, referred, designed, published, found, considered,
# Nearest to s: owning, wickham, shelled, hilberg, sata, whose, reproductive, settlers,
# Nearest to most: many, some, more, among, codepoint, less, molarity, amar,
# Nearest to were: are, was, have, been, while, had, those, although,
# Nearest to while: although, when, though, however, tetrahedron, were, before, after,
# Nearest to into: from, through, across, nerva, over, under, between, hamza,
# Nearest to in: within, during, of, until, since, at, among, throughout,
# Nearest to no: any, ministership, semantics, memorials, scandinavia, beauvoir, metre, predictive,
# Nearest to be: been, become, have, being, was, are, is, repopulated,
# Nearest to also: often, still, now, which, never, there, generally, actually,
# Nearest to that: which, what, however, this, roh, there, often, it,
# Nearest to between: with, within, among, in, types, remarry, into, coding,
# Nearest to world: lyrical, asb, sickness, temple, legends, histological, breakbeats, cider,
# Average loss at step 62000: 3.243322
# Average loss at step 64000: 3.255204
# Average loss at step 66000: 3.399849
# Average loss at step 68000: 3.395745
# Average loss at step 70000: 3.356192
# Nearest to if: when, though, where, although, while, before, sinhalese, philanthropy,
# Nearest to many: some, several, these, various, all, most, numerous, other,
# Nearest to a: the, another, any, enough, alfv, genitals, herbie, lamarck,
# Nearest to used: known, written, responsible, found, referred, considered, available, designed,
# Nearest to s: shelled, faroe, whose, regroup, reproductive, outboard, pneumoniae, roca,
# Nearest to most: more, many, less, some, quite, disappearance, particularly, among,
# Nearest to were: are, was, have, had, be, been, although, including,
# Nearest to while: although, however, though, when, where, before, if, are,
# Nearest to into: from, through, across, nerva, hamza, between, lvares, graphic,
# Nearest to in: within, during, on, until, from, throughout, at, for,
# Nearest to no: any, there, nucleotide, significantly, scandinavia, beauvoir, semantics, ministership,
# Nearest to be: been, is, become, have, being, were, was, repopulated,
# Nearest to also: still, now, often, which, actually, usually, never, sometimes,
# Nearest to that: which, however, what, roh, but, this, sahrawi, where,
# Nearest to between: within, with, among, ebirah, deprecating, from, types, into,
# Nearest to world: sickness, lyrical, breakbeats, graduation, inflation, dacian, u, upset,
# Average loss at step 72000: 3.370710
# Average loss at step 74000: 3.349664
# Average loss at step 76000: 3.314028
# Average loss at step 78000: 3.350166
# Average loss at step 80000: 3.377304
# Nearest to if: when, though, although, where, before, philanthropy, since, sinhalese,
# Nearest to many: some, several, various, these, most, numerous, all, both,
# Nearest to a: another, the, archimandrite, alfv, hairpin, grouse, crewmen, every,
# Nearest to used: written, known, referred, described, responsible, available, called, found,
# Nearest to s: owning, isbn, amplify, shelled, condor, saab, reproductive, pneumoniae,
# Nearest to most: more, many, less, some, particularly, among, disappearance, quite,
# Nearest to were: are, was, had, have, became, although, been, be,
# Nearest to while: although, though, when, however, and, but, after, during,
# Nearest to into: through, across, from, nerva, back, between, soyuz, dinosauria,
# Nearest to in: within, during, at, on, until, throughout, around, between,
# Nearest to no: any, little, metre, ministership, there, semantics, igg, approximately,
# Nearest to be: been, being, become, have, were, is, resist, easily,
# Nearest to also: still, now, often, which, sometimes, actually, never, generally,
# Nearest to that: which, however, but, what, sindhu, where, this, gayoom,
# Nearest to between: within, among, with, in, from, ebirah, types, remarry,
# Nearest to world: sickness, dacian, u, upset, inflation, charity, lyrical, superhero,
# Average loss at step 82000: 3.402960
# Average loss at step 84000: 3.405918
# Average loss at step 86000: 3.387888
# Average loss at step 88000: 3.348776
# Average loss at step 90000: 3.364032
# Nearest to if: when, though, where, before, although, since, philanthropy, resembles,
# Nearest to many: some, several, various, these, numerous, most, all, linearly,
# Nearest to a: another, the, every, any, ceded, genitals, hairpin, museo,
# Nearest to used: written, known, referred, considered, called, found, responsible, described,
# Nearest to s: obadiah, whose, modernist, schr, eschatological, owning, valved, unicellular,
# Nearest to most: many, more, less, some, among, particularly, especially, codepoint,
# Nearest to were: are, was, had, have, while, although, became, zealot,
# Nearest to while: although, though, when, before, after, were, until, during,
# Nearest to into: through, from, across, nerva, between, back, wheelchair, under,
# Nearest to in: within, during, under, until, with, at, brodie, around,
# Nearest to no: any, little, only, counselors, pestilence, metre, drastically, trapezohedron,
# Nearest to be: been, is, become, being, was, have, lead, were,
# Nearest to also: often, now, still, actually, never, which, who, generally,
# Nearest to that: which, however, what, but, whom, roh, lendl, reformers,
# Nearest to between: with, within, among, ebirah, in, into, rts, lagging,
# Nearest to world: upset, sickness, inflation, irrelevent, histological, helsinki, operatorname, legends,
# Average loss at step 92000: 3.395080
# Average loss at step 94000: 3.256677
# Average loss at step 96000: 3.357412
# Average loss at step 98000: 3.241853
# Average loss at step 100000: 3.357562
# Nearest to if: when, though, where, before, although, philanthropy, resembles, then,
# Nearest to many: some, several, these, numerous, various, all, few, those,
# Nearest to a: another, the, assemblers, golem, any, internecine, diadem, herndon,
# Nearest to used: referred, written, considered, known, found, designed, given, able,
# Nearest to s: his, jacobins, my, whose, shelled, knesset, roca, twayne,
# Nearest to most: more, less, especially, particularly, many, codepoint, some, among,
# Nearest to were: are, have, was, these, had, include, aspired, although,
# Nearest to while: although, when, though, however, before, where, but, are,
# Nearest to into: through, across, from, nerva, bring, between, within, off,
# Nearest to in: during, within, until, from, throughout, near, of, on,
# Nearest to no: any, little, only, trapezohedron, metre, circumstantial, parcels, daria,
# Nearest to be: been, being, have, is, become, are, resist, easily,
# Nearest to also: actually, now, still, often, never, generally, who, sometimes,
# Nearest to that: which, what, however, roh, but, whom, who, michaels,
# Nearest to between: with, within, among, ebirah, rts, into, remarry, in,
# Nearest to world: sickness, year, charity, country, legends, histological, u, bridgewater,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    # switch lablels and data
    batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
    batch_data = batch_data.reshape((batch_size,))
    batch_labels = batch_labels.reshape((batch_size, 1))
        
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.763053
# Nearest to UNK: habibullah, exchequer, dred, dubbing, flee, bonhomme, brit, plagues,
# Nearest to during: tolerances, arb, refusal, adrift, affairs, symmetrically, abbess, wastes,
# Nearest to the: agriculturally, drivers, utilized, barry, dass, scrupulous, vlad, spread,
# Nearest to over: settles, childish, amazonian, draftees, sooner, proves, thorium, bottlenecks,
# Nearest to first: kitab, yvonne, defendant, bromley, levees, modernist, politico, parsed,
# Nearest to people: gratis, telecoms, sphincter, ditches, cardamom, eda, letting, kites,
# Nearest to will: mustard, amyotrophic, hazlitt, coles, emf, auk, throes, fleeing,
# Nearest to by: lien, intersected, stands, storage, czechoslovak, betting, den, tynwald,
# Nearest to b: algemeen, meritocratic, standoff, examiners, aquaria, anchor, grothendieck, veronica,
# Nearest to no: metamorphoses, patrolled, trips, transept, dunraven, urea, grade, iss,
# Nearest to also: joanna, pronounce, khmer, portrayed, linus, engineered, honorum, brains,
# Nearest to for: snows, dixie, unlikely, moroccans, masoretic, abol, xin, contestant,
# Nearest to about: ninlil, martingale, omnipresent, drainage, kilobytes, ligatures, chi, phonology,
# Nearest to years: hearses, outs, odp, tetzel, magnetically, slavs, hm, arranged,
# Nearest to history: occult, anonymity, ein, kennedy, ridinghood, gimel, weu, malabar,
# Nearest to is: equipped, abridgment, superconductor, retriever, suggestibility, tourism, invasion, congenital,
# Average loss at step 2000: 4.353498
# Average loss at step 4000: 3.868521
# Average loss at step 6000: 3.784338
# Average loss at step 8000: 3.689488
# Average loss at step 10000: 3.612382
# Nearest to UNK: kirby, masoretes, disruption, franken, hindustani, writers, george, schoolchildren,
# Nearest to during: tolerances, sand, affairs, symmetrically, at, adrift, refusal, carbonaceous,
# Nearest to the: a, its, this, his, an, penzias, dme, s,
# Nearest to over: proves, draftees, amazonian, cvd, childish, settles, correspondence, spicy,
# Nearest to first: modernist, copious, violate, took, formal, kitab, emperors, illegality,
# Nearest to people: edwards, monarchical, letting, stiffness, aron, shrubs, copper, child,
# Nearest to will: can, might, coles, should, entering, would, cactus, typically,
# Nearest to by: was, as, on, lien, through, in, be, and,
# Nearest to b: algemeen, d, cryptozoology, inanna, grothendieck, familia, ears, underpinning,
# Nearest to no: trips, nicosia, she, iss, urea, it, preach, renderings,
# Nearest to also: which, often, gadamer, she, usually, now, overtaken, there,
# Nearest to for: godzilla, provoking, and, lbs, refined, brest, abol, of,
# Nearest to about: ligatures, omnipresent, albatrosses, ninlil, lassa, phonology, hard, martingale,
# Nearest to years: outs, hearses, triadic, disfigured, months, slavs, pleasant, wracked,
# Nearest to history: occult, ein, nicomedia, illness, kennedy, henry, charlotte, homilies,
# Nearest to is: was, are, has, be, altruistic, code, mpa, crystallography,
# Average loss at step 12000: 3.601763
# Average loss at step 14000: 3.575123
# Average loss at step 16000: 3.405386
# Average loss at step 18000: 3.457640
# Average loss at step 20000: 3.540952
# Nearest to UNK: tallest, johns, douglas, callaghan, kirby, trophy, distracting, regained,
# Nearest to during: in, at, after, tolerances, adrift, dueling, refusal, arb,
# Nearest to the: its, their, his, this, a, an, dme, any,
# Nearest to over: settles, draftees, correspondence, cvd, hackman, proves, fluorescence, spicy,
# Nearest to first: modernist, formal, illegality, copious, kitab, je, greatest, dimensional,
# Nearest to people: edwards, antisemitism, stiffness, religions, letting, monarchical, canary, sourced,
# Nearest to will: can, would, should, may, might, could, entering, must,
# Nearest to by: in, be, prerecorded, were, with, alice, through, merits,
# Nearest to b: d, algemeen, hiss, apical, blending, alias, ears, french,
# Nearest to no: nicosia, trips, a, diameter, patrolled, preach, homotopy, urea,
# Nearest to also: now, which, often, gadamer, usually, not, who, never,
# Nearest to for: of, with, provoking, in, blindness, on, and, ennedi,
# Nearest to about: albatrosses, omnipresent, highgate, dienes, embalming, ninlil, around, copernican,
# Nearest to years: outs, months, hearses, pleasant, disfigured, elle, amhara, times,
# Nearest to history: homilies, occult, henry, burial, nicomedia, kennedy, ein, clairvaux,
# Nearest to is: was, are, has, be, code, were, but, keel,
# Average loss at step 22000: 3.508072
# Average loss at step 24000: 3.489893
# Average loss at step 26000: 3.480915
# Average loss at step 28000: 3.478858
# Average loss at step 30000: 3.500962
# Nearest to UNK: spore, kurgan, battista, sensibilities, johns, revitalized, kirby, writers,
# Nearest to during: after, in, at, since, tolerances, affairs, carbonaceous, until,
# Nearest to the: its, their, his, a, some, this, her, permanence,
# Nearest to over: hackman, childish, pleasant, within, masoretic, cvd, settles, txt,
# Nearest to first: second, greatest, modernist, last, illegality, company, je, dimensional,
# Nearest to people: edwards, antisemitism, countries, stiffness, letting, those, invariable, many,
# Nearest to will: can, would, should, may, could, might, must, entering,
# Nearest to by: in, as, were, was, lobbied, from, aston, alice,
# Nearest to b: d, algemeen, shortening, malignancies, ears, porfirio, hiss, abadan,
# Nearest to no: nicosia, trips, any, already, there, se, a, diameter,
# Nearest to also: often, now, which, never, who, it, originally, sometimes,
# Nearest to for: provoking, with, schwarzenegger, abol, when, of, mccartney, ansgar,
# Nearest to about: lassa, on, albatrosses, beyond, embalming, manifolds, sad, omnipresent,
# Nearest to years: months, outs, times, pleasant, days, sequel, hearses, disfigured,
# Nearest to history: homilies, tv, kennedy, occult, burial, nicomedia, federal, frogs,
# Nearest to is: was, has, are, were, fundraising, be, does, while,
# Average loss at step 32000: 3.501677
# Average loss at step 34000: 3.495189
# Average loss at step 36000: 3.458318
# Average loss at step 38000: 3.297870
# Average loss at step 40000: 3.428033
# Nearest to UNK: image, icd, figurative, approximants, l, commensurate, bruun, swf,
# Nearest to during: after, at, since, in, until, on, before, rebuke,
# Nearest to the: this, its, any, each, their, a, his, rence,
# Nearest to over: greater, hackman, nearly, about, cvd, txt, iso, correspondence,
# Nearest to first: second, next, last, illegality, greatest, best, cologne, steep,
# Nearest to people: edwards, antisemitism, those, others, efforts, maccabees, countries, inhabitants,
# Nearest to will: can, would, could, may, should, must, might, does,
# Nearest to by: with, through, prerecorded, ip, be, imprison, been, as,
# Nearest to b: d, c, soliciting, algemeen, holberg, shortening, curled, f,
# Nearest to no: nicosia, any, already, there, trips, yuri, ystok, usually,
# Nearest to also: often, which, now, usually, still, sometimes, never, widely,
# Nearest to for: in, abol, when, schwarzenegger, with, if, ansgar, provoking,
# Nearest to about: lassa, injurious, embalming, beyond, omnipresent, over, sad, manifolds,
# Nearest to years: months, days, times, decades, outs, pleasant, malaise, sequel,
# Nearest to history: homilies, list, occult, sinti, babe, kennedy, boece, clairvaux,
# Nearest to is: was, has, are, be, damme, becomes, reluctantly, if,
# Average loss at step 42000: 3.431435
# Average loss at step 44000: 3.455875
# Average loss at step 46000: 3.456030
# Average loss at step 48000: 3.353257
# Average loss at step 50000: 3.378518
# Nearest to UNK: normalization, et, backfire, tt, methyl, sulfuric, justified, ambrose,
# Nearest to during: after, at, in, when, since, until, while, underhill,
# Nearest to the: its, their, his, some, a, this, nick, mohr,
# Nearest to over: greater, txt, enthusiast, liquidity, masoretic, magistrates, pleasant, about,
# Nearest to first: last, second, greatest, illegality, next, swept, importing, only,
# Nearest to people: inhabitants, letting, edwards, children, countries, religions, jews, antisemitism,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to by: through, was, kludge, in, carloman, nora, dreadnought, been,
# Nearest to b: d, c, f, soliciting, holberg, circa, seizes, paasikivi,
# Nearest to no: any, trips, nicosia, suggesting, pelletier, a, se, ystok,
# Nearest to also: often, now, which, never, still, originally, sometimes, usually,
# Nearest to for: abol, provoking, schwarzenegger, while, sheik, historical, colloids, cameo,
# Nearest to about: embalming, beyond, inoculated, injurious, sad, excluding, anniversaries, lassa,
# Nearest to years: months, days, times, decades, pleasant, year, outs, sequel,
# Nearest to history: list, homilies, sinti, babe, aldous, jewish, daddy, brunei,
# Nearest to is: was, are, has, were, contains, be, crystallography, becomes,
# Average loss at step 52000: 3.438089
# Average loss at step 54000: 3.427236
# Average loss at step 56000: 3.437170
# Average loss at step 58000: 3.399244
# Average loss at step 60000: 3.391992
# Nearest to UNK: kellermann, mescaline, objectivism, whisper, summand, rm, deconstructing, erlk,
# Nearest to during: after, in, before, since, following, when, underhill, until,
# Nearest to the: their, its, a, his, any, this, each, our,
# Nearest to over: between, greater, txt, substitutions, about, settles, into, magistrates,
# Nearest to first: last, second, next, greatest, same, best, only, third,
# Nearest to people: individuals, edwards, inhabitants, those, persons, countries, scholars, jews,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to by: through, be, spires, carloman, with, under, kludge, underestimate,
# Nearest to b: d, c, f, p, seizes, m, platinum, z,
# Nearest to no: nicosia, pelletier, any, trips, suggesting, yuri, se, anthropomorphized,
# Nearest to also: now, often, sometimes, never, still, usually, which, rarely,
# Nearest to for: provoking, of, including, abol, when, without, schwarzenegger, and,
# Nearest to about: beyond, over, embalming, around, suspensions, excluding, sad, anniversaries,
# Nearest to years: months, days, times, decades, year, weeks, pleasant, shortly,
# Nearest to history: list, babe, sinti, references, jewish, imbalance, journal, asian,
# Nearest to is: was, are, has, be, became, gives, does, becomes,
# Average loss at step 62000: 3.239001
# Average loss at step 64000: 3.253502
# Average loss at step 66000: 3.407680
# Average loss at step 68000: 3.393175
# Average loss at step 70000: 3.355495
# Nearest to UNK: com, johnson, grayson, apcs, aqdas, erlk, skyrocketed, herpes,
# Nearest to during: after, in, since, before, until, saw, underhill, at,
# Nearest to the: their, its, a, any, this, these, our, each,
# Nearest to over: about, greater, substitutions, pleasant, within, around, liquidity, settles,
# Nearest to first: last, second, next, same, best, third, greatest, final,
# Nearest to people: individuals, members, persons, inhabitants, men, others, edwards, children,
# Nearest to will: would, could, may, can, should, must, might, cannot,
# Nearest to by: through, be, using, was, in, spires, carloman, snap,
# Nearest to b: d, f, p, z, rationalisation, c, syllabic, landis,
# Nearest to no: there, any, pelletier, little, yuri, ystok, dunraven, finiteness,
# Nearest to also: now, never, often, usually, still, which, sometimes, generally,
# Nearest to for: in, provoking, of, sheik, schwarzenegger, without, abol, heiden,
# Nearest to about: beyond, over, around, embalming, on, excluding, sad, barclays,
# Nearest to years: months, days, decades, times, weeks, centuries, year, malaise,
# Nearest to history: list, imbalance, journal, sinti, jewish, asian, references, miko,
# Nearest to is: was, has, are, be, gives, contains, does, refutable,
# Average loss at step 72000: 3.373923
# Average loss at step 74000: 3.350119
# Average loss at step 76000: 3.316315
# Average loss at step 78000: 3.346194
# Average loss at step 80000: 3.381661
# Nearest to UNK: douglas, jones, moore, physician, davis, unaids, johnson, tahoe,
# Nearest to during: after, in, when, before, until, since, at, saw,
# Nearest to the: their, a, its, hemp, this, his, dancehall, yag,
# Nearest to over: around, within, between, about, into, through, across, greater,
# Nearest to first: last, second, next, same, third, greatest, best, only,
# Nearest to people: individuals, persons, children, men, members, societies, those, inhabitants,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to by: through, carloman, spires, vax, dopant, from, during, be,
# Nearest to b: d, c, f, p, z, landis, genoese, rationalisation,
# Nearest to no: little, se, pelletier, nicosia, yuri, any, rejects, maimonides,
# Nearest to also: still, now, never, sometimes, often, which, usually, commonly,
# Nearest to for: nora, colloids, abol, contrasting, schwarzenegger, sheik, while, brest,
# Nearest to about: over, anniversaries, embalming, around, beyond, pmid, excluding, barclays,
# Nearest to years: months, days, times, decades, weeks, centuries, year, pleasant,
# Nearest to history: list, journal, sinti, imbalance, manufacturing, charge, babe, servo,
# Nearest to is: was, has, are, became, although, becomes, clarified, be,
# Average loss at step 82000: 3.407915
# Average loss at step 84000: 3.412124
# Average loss at step 86000: 3.386537
# Average loss at step 88000: 3.352612
# Average loss at step 90000: 3.365058
# Nearest to UNK: phenomenological, maulana, l, imperium, callaghan, wilkinson, householder, engineer,
# Nearest to during: after, before, until, in, through, saw, since, at,
# Nearest to the: this, its, each, his, any, a, cho, their,
# Nearest to over: around, within, off, through, liquidity, nva, txt, about,
# Nearest to first: last, second, next, same, greatest, oldest, final, illegality,
# Nearest to people: children, individuals, players, members, persons, women, visitors, societies,
# Nearest to will: could, can, would, may, should, must, might, cannot,
# Nearest to by: through, with, carloman, including, on, during, towards, and,
# Nearest to b: f, d, c, genoese, z, p, g, landis,
# Nearest to no: little, any, nothing, ystok, trips, triode, there, nicosia,
# Nearest to also: which, often, never, still, now, sometimes, commonly, usually,
# Nearest to for: nora, abol, of, during, without, while, rarefied, snows,
# Nearest to about: silhouette, beyond, barclays, embalming, inoculated, over, around, incorporeal,
# Nearest to years: days, months, decades, weeks, centuries, times, year, hours,
# Nearest to history: list, journal, imbalance, sinti, charge, servo, eurydice, ontology,
# Nearest to is: was, has, are, becomes, be, does, became, although,
# Average loss at step 92000: 3.397392
# Average loss at step 94000: 3.253230
# Average loss at step 96000: 3.362294
# Average loss at step 98000: 3.239823
# Average loss at step 100000: 3.359122
# Nearest to UNK: here, deconstructing, amazement, jerk, http, ne, distracting, narcotic,
# Nearest to during: after, in, before, since, until, through, throughout, when,
# Nearest to the: their, his, our, its, your, a, this, each,
# Nearest to over: within, around, into, through, between, across, off, affleck,
# Nearest to first: last, second, next, third, final, same, best, illegality,
# Nearest to people: children, individuals, persons, players, jews, visitors, inhabitants, those,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to by: through, when, including, sharply, fincher, be, carloman, ess,
# Nearest to b: d, f, french, eudes, z, algemeen, c, colloquially,
# Nearest to no: little, any, se, yuri, triode, caveat, ystok, trips,
# Nearest to also: never, now, still, sometimes, actually, often, usually, commonly,
# Nearest to for: when, without, while, provoking, if, schwarzenegger, after, including,
# Nearest to about: around, silhouette, inoculated, beyond, embalming, evangelicalism, barclays, incorporeal,
# Nearest to years: days, months, decades, weeks, year, centuries, times, hours,
# Nearest to history: list, imbalance, journal, references, charge, sinti, intensive, mind,
# Nearest to is: was, has, are, became, becomes, seems, be, refutable,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
